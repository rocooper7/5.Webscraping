# %% [markdown]
# ## Avenged Sevenfold

# %% [markdown]
# Links útiles para la clase:
# - [Documentación de Spotify - Artistas](https://developer.spotify.com/documentation/web-api/reference/artists/)
# - [Avenged Sevenfold en Spotify](https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs)
# - [Registrá tu aplicación](https://developer.spotify.com/documentation/general/guides/app-settings/#register-your-app)

# %%
import requests

# %%
artist_id = '0nmQIMXWTXfhgOBdNzhGOs'

# %%
url_base = 'https://api.spotify.com/v1'

# %%
ep_artist = f'/artists/{artist_id}'

# %%
artist_link = url_base + ep_artist

# %%
r = requests.get(artist_link)

# %%
r.status_code
# Out:
# 401

# %%
r.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %% [markdown]
# Links útiles para la clase:
# - [Guía de autorización de Spotify](https://developer.spotify.com/documentation/general/guides/authorization-guide/)
# - https://www.base64encode.org/
# - [Endpoint de búsqueda de Spotify](https://developer.spotify.com/documentation/web-api/reference/search/search/)

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type': 'client_credentials'}

# %% [markdown]
# Authorization: Basic base64 encoded client_id : client_secret

# %%
headers = {'Authorization': 'Basic NDRiN2IzNmVjMTQ1NDY3ZjlhOWVlYWY3ZTQxN2NmOGI6N2I0YWE3YTBlZjQ4NDQwNDhhYjFkMjI0MzBhMWViMWY='}

# %%
r = requests.post(token_url, data=params, headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQBtwr6Qxu2_nncuFmVmFQXxPPPOxElfEpKmaBG4_eg_SXbWT2abQODJeQhCvXquNTFpuT8rSOLqeW5FV7I',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
token = r.json()['access_token']
token
# Out:
# 'BQBtwr6Qxu2_nncuFmVmFQXxPPPOxElfEpKmaBG4_eg_SXbWT2abQODJeQhCvXquNTFpuT8rSOLqeW5FV7I'

# %%
header = {"Authorization": f"Bearer {token}"}

# %%
r = requests.get(artist_link, headers= header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'},
#  'followers': {'href': None, 'total': 4180075},
#  'genres': ['alternative metal', 'nu metal'],
#  'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs',
#  'id': '0nmQIMXWTXfhgOBdNzhGOs',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/e8469ef3c4e45f9574dc963a69043ac3f3e58d41',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/73b9076ebae4987573b1c6dde101d4e1961d91a6',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/50bb40412699a5e3c8a5a5752c1cd3fc9bfac687',
#    'width': 160}],
#  'name': 'Avenged Sevenfold',
#  'popularity': 78,
#  'type': 'artist',
#  'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}

# %%
print(r.json()['followers']['total'])
print(r.json()['name'])
print(r.json()['genres'][0])
# Out:
# 4180075
# Avenged Sevenfold
# alternative metal

# %% [markdown]
# ## Busqueda Artista

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q': "Avenged+Sevenfold", 'type':'artist', 'market':'MX'}

# %%
busqueda = requests.get(url_busqueda, headers= header, params= search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
# busqueda.json()
print(busqueda.json())
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Avenged%2BSevenfold&type=artist&market=MX&offset=0&limit=20', 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'followers': {'href': None, 'total': 4180075}, 'genres': ['alternative metal', 'nu metal'], 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/e8469ef3c4e45f9574dc963a69043ac3f3e58d41', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/73b9076ebae4987573b1c6dde101d4e1961d91a6', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/50bb40412699a5e3c8a5a5752c1cd3fc9bfac687', 'width': 160}], 'name': 'Avenged Sevenfold', 'popularity': 78, 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'limit': 20, 'next': None, 'offset': 0, 'previous': None, 'total': 1}}

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])
df.head(2)
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/0...
#
#                           followers                         genres  \
# 0  {'href': None, 'total': 4180075}  [alternative metal, nu metal]
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/0nmQIMXWTXf...  0nmQIMXWTXfhgOBdNzhGOs
#
#                                               images               name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Avenged Sevenfold
#
#    popularity    type                                    uri
# 0          78  artist  spotify:artist:0nmQIMXWTXfhgOBdNzhGOs

# %%
df.sort_values(by='popularity', ascending=False).loc[0,'id']
# Out:
# '0nmQIMXWTXfhgOBdNzhGOs'

# %% [markdown]
# ## Obteniendo Token (Función)

# %%
import base64
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id + ':' + client_secret, 'utf-8'))
    token_url = 'https://accounts.spotify.com/api/token'
    params = {'grant_type':'client_credentials'}
    header = {'Authorization': 'Basic ' + str(encoded, 'utf-8')}
    r = requests.post(token_url, headers= header, data= params)
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    print(f'Token válido por {r.json()["expires_in"]} segundos.')
    return r.json()['access_token']

# %%
client_id = '44b7b36ec145467f9a9eeaf7e417cf8b'
client_secret = '7b4aa7a0ef4844048ab1d22430a1eb1f'

# %%
token = get_token(client_id, client_secret)
token
# Out:
# Token válido por 3600 segundos.
# 'BQATf8z5avXHkh5nro5Is0pJPHeeHTYdGAZpj5OqDok5ce5WlltHBKCw7MlyitRjSPAN6bin5vppOONIXII'

# %%
header = {"Authorization": f"Bearer {token}"}
header
# Out:
# {'Authorization': 'Bearer BQATf8z5avXHkh5nro5Is0pJPHeeHTYdGAZpj5OqDok5ce5WlltHBKCw7MlyitRjSPAN6bin5vppOONIXII'}

# %%
artist_im = requests.get(artist_link, headers= header)
artist_im.status_code
# Out:
# 200

# %%
artist_im.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'},
#  'followers': {'href': None, 'total': 4180075},
#  'genres': ['alternative metal', 'nu metal'],
#  'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs',
#  'id': '0nmQIMXWTXfhgOBdNzhGOs',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/e8469ef3c4e45f9574dc963a69043ac3f3e58d41',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/73b9076ebae4987573b1c6dde101d4e1961d91a6',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/50bb40412699a5e3c8a5a5752c1cd3fc9bfac687',
#    'width': 160}],
#  'name': 'Avenged Sevenfold',
#  'popularity': 78,
#  'type': 'artist',
#  'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}

# %% [markdown]
# ## Obteniendo Albums

# %%
params = {'country': 'MX'}

# %%
albums_im = requests.get(artist_link + '/albums', headers= header, params= params)
albums_im.status_code
# Out:
# 200

# %%
# albums_im.json()   #Para ver bien el json
print(albums_im.json()['items'])  #Albums
# Out:
# [{'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/7pb9ZipjQRimTjYOZpZ8lk'}, 'href': 'https://api.spotify.com/v1/albums/7pb9ZipjQRimTjYOZpZ8lk', 'id': '7pb9ZipjQRimTjYOZpZ8lk', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273e36fd37b8ca4b150c3412ab0', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02e36fd37b8ca4b150c3412ab0', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851e36fd37b8ca4b150c3412ab0', 'width': 64}], 'name': 'Live in the LBC', 'release_date': '2020-03-06', 'release_date_precision': 'day', 'total_tracks': 13, 'type': 'album', 'uri': 'spotify:album:7pb9ZipjQRimTjYOZpZ8lk'}, {'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6VcCunBnnw4BVkCit5rk7d'}, 'href': 'https://api.spotify.com/v1/albums/6VcCunBnnw4BVkCit5rk7d', 'id': '6VcCunBnnw4BVkCit5rk7d', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273185b6b614a78224229b94831', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02185b6b614a78224229b94831', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851185b6b614a78224229b94831', 'width': 64}], 'name': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:6VcCunBnnw4BVkCit5rk7d'}, {'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/0OJ2cB135AqvHEtfXifM5D'}, 'href': 'https://api.spotify.com/v1/albums/0OJ2cB135AqvHEtfXifM5D', 'id': '0OJ2cB135AqvHEtfXifM5D', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2734843e0f824a00334e811279c', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e024843e0f824a00334e811279c', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048514843e0f824a00334e811279c', 'width': 64}], 'name': 'The Stage (Deluxe Edition)', 'release_date': '2017-12-22', 'release_date_precision': 'day', 'total_tracks': 22, 'type': 'album', 'uri': 'spotify:album:0OJ2cB135AqvHEtfXifM5D'}, {'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/7GDwkEUs8AAIcSRKDQX9Wd'}, 'href': 'https://api.spotify.com/v1/albums/7GDwkEUs8AAIcSRKDQX9Wd', 'id': '7GDwkEUs8AAIcSRKDQX9Wd', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273975bddf01e6aee5927c7df25', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02975bddf01e6aee5927c7df25', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851975bddf01e6aee5927c7df25', 'width': 64}], 'name': ' ...

# %%
[(album['id'], album['name']) for album in albums_im.json()['items']]
# Out:
# [('7pb9ZipjQRimTjYOZpZ8lk', 'Live in the LBC'),
#  ('6VcCunBnnw4BVkCit5rk7d', 'Diamonds in the Rough'),
#  ('0OJ2cB135AqvHEtfXifM5D', 'The Stage (Deluxe Edition)'),
#  ('7GDwkEUs8AAIcSRKDQX9Wd', 'The Stage'),
#  ('0vINJeraREv5ySgWs57Dko', 'The Stage'),
#  ('0Qm2vu5VZp2MKLb6yTxSgT',
#   'Hail to the King: Deathbat (Original Video Game Soundtrack)'),
#  ('6V3hjAUhRZU5aLeNNxTOUo', 'Waking The Fallen: Resurrected'),
#  ('0ks45m1bsP2JsZpM5D2FFA', 'Hail to the King'),
#  ('1kZNgA27ewArSfE17yog8U', 'Nightmare'),
#  ('7vfuTRXIAYJz5Uc8SddnTr', 'Nightmare'),
#  ('4c7feTGejaAYDyEJuhL0BR', 'Avenged Sevenfold'),
#  ('0v3FHuvSb3f90AWW5uTqE7', 'Avenged Sevenfold'),
#  ('3Id3VUk9jSKBD1guNo1buF', 'Avenged Sevenfold'),
#  ('55tK4Ab7XHTOKkw0xDz3AA', 'City of Evil'),
#  ('0TdsEj0Ep5DCtuQ68Pw9Cb', 'City of Evil'),
#  ('3qyVLEW74vRMvVxNHjwKhk', 'Waking The Fallen'),
#  ('3Pi6o8NqDPlEBilGeMKi8q', 'Sounding The Seventh Trumpet'),
#  ('0QKfHcNAjUqQo6PyQrGPk9', 'Set Me Free'),
#  ('1cw8vqbfe9UetxpJmXNk5p', 'Black Reign'),
#  ('4cYx05jNL7Pz1AW0kcwoXi', 'Mad Hatter')]

# %% [markdown]
# ## Obteniendo Tracks

# %%
album_id = '0OJ2cB135AqvHEtfXifM5D'

# %%
album_ep = f'/albums/{album_id}'

# %%
album_link = url_base + album_ep

# %%
album_params = {'market':'MX'}

# %%
bnw = requests.get(album_link + '/tracks', headers= header, params= album_params)
bnw.status_code
# Out:
# 200

# %%
# bnw.json()
print(bnw.json())
# Out:
# {'href': 'https://api.spotify.com/v1/albums/0OJ2cB135AqvHEtfXifM5D/tracks?offset=0&limit=20&market=MX', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'disc_number': 1, 'duration_ms': 512024, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/69gBAQdpxvCsw34Bbf8MnD'}, 'href': 'https://api.spotify.com/v1/tracks/69gBAQdpxvCsw34Bbf8MnD', 'id': '69gBAQdpxvCsw34Bbf8MnD', 'is_local': False, 'is_playable': True, 'name': 'The Stage', 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:69gBAQdpxvCsw34Bbf8MnD'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'disc_number': 1, 'duration_ms': 258748, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/54eHsmpBTFQaFsQ44Uh1C9'}, 'href': 'https://api.spotify.com/v1/tracks/54eHsmpBTFQaFsQ44Uh1C9', 'id': '54eHsmpBTFQaFsQ44Uh1C9', 'is_local': False, 'is_playable': True, 'name': 'Paradigm', 'preview_url': None, 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:54eHsmpBTFQaFsQ44Uh1C9'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'disc_number': 1, 'duration_ms': 401213, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/3XEnD6waKU6E67IJXGURga'}, 'href': 'https://api.spotify.com/v1/tracks/3XEnD6waKU6E67IJXGURga', 'id': '3XEnD6waKU6E67IJXGURga', 'is_local': False, 'is_playable': True, 'name': 'Sunny Disposition', 'preview_url': None, 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:3XEnD6waKU6E67IJXGURga'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'disc_number': 1, 'duration_ms': 221973, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/5uZf5fcY88UMoJtCRbSDKg'}, 'href': 'https://api.spotify.com/v1/tracks/5uZf5fcY88UMoJtCRbSDKg', 'id': '5uZf5fcY88UMoJtCRbSDKg', 'is_local': False, 'is_playable': True, 'name': 'God Damn', 'preview_url': None, 'track_number': 4, 'type': 'track', 'uri': 'spotify:track:5uZf5fcY88UMoJtCRbSDKg'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'disc_number': 1, 'duration_ms': 334600, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/7anar50LfTXvhMMuZfvZG2'}, 'href': 'https://api.spotify.com/v1/tracks/7anar50LfTXvhMMuZfvZG2', 'id': '7anar50LfTXvhMMuZfvZG2', 'is_local': False, 'is_playable': True, 'name': 'Creating God', 'preview_url': None, 'track_number': 5, 'type': 'track', 'uri': 'spotify:track:7anar50LfTXvhMMuZfvZG2'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'}, 'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs', 'id': '0nmQIMXWTXfhgOBdNzhGOs', 'name': 'Avenged Sevenfold', 'type': 'artist', 'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}], 'disc_number ...

# %%
bnw.json()['items'][0]  #Primer cancion del disco (Lista de Diccionarios)
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'},
#    'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs',
#    'id': '0nmQIMXWTXfhgOBdNzhGOs',
#    'name': 'Avenged Sevenfold',
#    'type': 'artist',
#    'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}],
#  'disc_number': 1,
#  'duration_ms': 512024,
#  'explicit': False,
#  'external_urls': {'spotify': 'https://open.spotify.com/track/69gBAQdpxvCsw34Bbf8MnD'},
#  'href': 'https://api.spotify.com/v1/tracks/69gBAQdpxvCsw34Bbf8MnD',
#  'id': '69gBAQdpxvCsw34Bbf8MnD',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'The Stage',
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:69gBAQdpxvCsw34Bbf8MnD'}

# %%
[(track['id'], track['name']) for track in bnw.json()['items']]
# Out:
# [('69gBAQdpxvCsw34Bbf8MnD', 'The Stage'),
#  ('54eHsmpBTFQaFsQ44Uh1C9', 'Paradigm'),
#  ('3XEnD6waKU6E67IJXGURga', 'Sunny Disposition'),
#  ('5uZf5fcY88UMoJtCRbSDKg', 'God Damn'),
#  ('7anar50LfTXvhMMuZfvZG2', 'Creating God'),
#  ('5kYhvoTzP1xwiEQBzKAbyh', 'Angels'),
#  ('710I1qNFgsZBCco12BvsXg', 'Simulation'),
#  ('0s58fNrvimb1xMwPF0T35r', 'Higher'),
#  ('5QAYgWH077T3F8kAcVtQs7', 'Roman Sky'),
#  ('2lwIcqxJAGxwHcOZCjhNEV', 'Fermi Paradox'),
#  ('5A93W5YIoFLWP1TNc4oPvg', 'Exist'),
#  ('6Gcv1c96EIihHdJeERkpc8', 'Dose'),
#  ('3KgOhRLuKXd61GgLzdBZqd', 'Retrovertigo'),
#  ('2oZSBEtzUtq70iQwpNjrnk', 'Malagueña Salerosa'),
#  ('071hmHI51coELRK8hoH12U', 'Runaway'),
#  ('1kISGVJoCqozjc4280wBcU', 'As Tears Go By'),
#  ('4JwxJm8zCPbc1DMcfVdbBl', 'Wish You Were Here'),
#  ('59x9anKxA7gNiDvqbtTzmS', 'God Only Knows'),
#  ('1L5elvXhJbDj9yzDFiTpuy', 'The Stage - Live from London'),
#  ('1HDFbX7YMhCK7L8QeTXOOZ', 'Paradigm - Live from London')]

# %% [markdown]
# ## Obteniendo Discografía (Función)

# %%
def obtener_discografia(artist_id, token, return_name = False, page_limit = 50, country = None):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    header = {'authorization': f'Bearer {token}'}
    params = {'limit' : page_limit, 
              'offset': 0, 
              'country': country}
    
    lista = []
    r = requests.get(url, params=params, headers=header)
    
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name'],item['release_date'],item['artists'][0]['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        
        if return_name:
            lista += [(item['id'], item['name'],item['release_date'],item['artists'][0]['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
            
    return lista

# %% [markdown]
# ## Obteniendo Tracks (Función)

# %%
def obtener_tracks(album_id, token, return_name=False, page_limit=50, market=None):
    url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit, 
              'offset': 0,
              'market': market}
    lista = []
    r = requests.get(url, params=params, headers=header)
    
    if r.status_code != 200:
        print('Error en request.', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header) # El resto de los parámetros están dentro de la URL
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %% [markdown]
# Utilizando estas funciones podemos obtener todos las canciones que tiene un artista publicadas en Spotify

# %%
for album in obtener_discografia(artist_id, token, return_name=True, country='MX'):
    print(album[1])   #album[1], valor 2 de la tupla
    for track in obtener_tracks(album[0], token, return_name=True, market='MX'):  #album[0], valor 1 de la tupla
        print('\t', track[1])
# Out:
# Live in the LBC
# 	 Intro - Live
# 	 Critical Acclaim - Live
# 	 Second Heartbeat - Live
# 	 Afterlife - Live
# 	 Beast and the Harlot - Live
# 	 Scream - Live
# 	 Seize the Day - Live
# 	 Walk - Live
# 	 Bat Country - Live
# 	 Almost Easy - Live
# 	 Gunslinger - Live
# 	 Unholy Confessions - Live
# 	 A Little Piece of Heaven - Live
# Diamonds in the Rough
# 	 Demons
# 	 Girl I Know
# 	 Crossroads
# 	 Flash of the Blade
# 	 Until the End
# 	 Tension
# 	 Walk
# 	 The Fight
# 	 Dancing Dead
# 	 Almost Easy - Chris Lord-Alge Mix
# 	 Afterlife - Alternate Version
# 	 St. James
# 	 Set Me Free
# 	 4:00 AM
# 	 Lost It All
# 	 Paranoid
# The Stage (Deluxe Edition)
# 	 The Stage
# 	 Paradigm
# 	 Sunny Disposition
# 	 God Damn
# 	 Creating God
# 	 Angels
# 	 Simulation
# 	 Higher
# 	 Roman Sky
# 	 Fermi Paradox
# 	 Exist
# 	 Dose
# 	 Retrovertigo
# 	 Malagueña Salerosa
# 	 Runaway
# 	 As Tears Go By
# 	 Wish You Were Here
# 	 God Only Knows
# 	 The Stage - Live from London
# 	 Paradigm - Live from London
# 	 The NInja, The Pinto, The Dan Marino
# 	 Cheerleading Is Big Business
# 	 Glass Socket / Broken Jaw
# 	 Away From Here
# 	 Aside
# 	 Possession (Not The One By Danzig)
# 	 Out A Luck
# 	 Who’s Your Daddy (Acoustic)
# 	 Darkness Surrounding
# 	 That Hideous Strength

# %%
info = []
for album in obtener_discografia(artist_id, token, return_name= True, country='MX'):    
    for track in obtener_tracks(album[0], token, return_name= True, market='MX'):
        dicc = {} 
        dicc['artist'] = album[3]
        dicc['id_album'] = album[0]
        dicc['album'] = album[1]
        dicc['release_date'] = album[2]
        dicc['track'] = track[1]
        info.append(dicc)

print(info)
# Out:
# [{'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Intro - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Critical Acclaim - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Second Heartbeat - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Afterlife - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Beast and the Harlot - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Scream - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Seize the Day - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Walk - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Bat Country - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Almost Easy - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Gunslinger - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'Unholy Confessions - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '7pb9ZipjQRimTjYOZpZ8lk', 'album': 'Live in the LBC', 'release_date': '2020-03-06', 'track': 'A Little Piece of Heaven - Live'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Demons'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Girl I Know'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Crossroads'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Flash of the Blade'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Until the End'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Tension'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Walk'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'The Fight'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Dancing Dead'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Almost Easy - Chris Lord-Alge Mix'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': '2020-02-07', 'track': 'Afterlife - Alternate Version'}, {'artist': 'Avenged Sevenfold', 'id_album': '6VcCunBnnw4BVkCit5rk7d', 'album': 'Diamonds in the Rough', 'release_date': ...

# %%
import pandas as pd
df = pd.DataFrame(info)
df
# Out:
#                 artist                id_album  \
# 0    Avenged Sevenfold  7pb9ZipjQRimTjYOZpZ8lk
# 1    Avenged Sevenfold  7pb9ZipjQRimTjYOZpZ8lk
# 2    Avenged Sevenfold  7pb9ZipjQRimTjYOZpZ8lk
# 3    Avenged Sevenfold  7pb9ZipjQRimTjYOZpZ8lk
# 4    Avenged Sevenfold  7pb9ZipjQRimTjYOZpZ8lk
# ..                 ...                     ...
# 750    Various Artists  01ablrFnNV5bXtdBrrKTVI
# 751    Various Artists  01ablrFnNV5bXtdBrrKTVI
# 752    Various Artists  01ablrFnNV5bXtdBrrKTVI
# 753    Various Artists  01ablrFnNV5bXtdBrrKTVI
# 754    Various Artists  01ablrFnNV5bXtdBrrKTVI
#
#                                  album release_date  \
# 0                      Live in the LBC   2020-03-06
# 1                      Live in the LBC   2020-03-06
# 2                      Live in the LBC   2020-03-06
# 3                      Live in the LBC   2020-03-06
# 4                      Live in the LBC   2020-03-06
# ..                                 ...          ...
# 750  Hopelessly Devoted to You, Vol. 4   2002-04-16
# 751  Hopelessly Devoted to You, Vol. 4   2002-04-16
# 752  Hopelessly Devoted to You, Vol. 4   2002-04-16
# 753  Hopelessly Devoted to You, Vol. 4   2002-04-16
# 754  Hopelessly Devoted to You, Vol. 4   2002-04-16
#
#                                   track
# 0                          Intro - Live
# 1               Critical Acclaim - Live
# 2               Second Heartbeat - Live
# 3                      Afterlife - Live
# 4           Beast and the Harlot - Live
# ..                                  ...
# 750  Possession (Not The One By Danzig)
# 751                          Out A Luck
# 752         Who’s Your Daddy (Acoustic)
# 753                Darkness Surrounding
# 754               That Hideous Strength
#
# [755 rows x 5 columns]

# %%
df.to_excel('AvengedSevenfold.xlsx',index = False)
